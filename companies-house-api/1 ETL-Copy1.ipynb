# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import query_companies_house as qch

# %%
import time

# %%
gender_pay_gap_data_201718_df = pd.read_csv(
    'UK_Gender_Pay_Gap_Data_2017_to_2018.csv')

# %%
gender_pay_gap_data_201718_df.head()
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
# 3                     123 EMPLOYEES LTD
# 4                          1610 LIMITED
#
#                                              Address CompanyNumber SicCodes  \
# 0  Bryanston House,\nBlandford,\nDorset,\nUnited ...      00226143    85310
# 1  19, Smith's Place,\nLeith Walk,\nEdinburgh,\nE...      SC016876    47730
# 2  Fusion Point,\nDumballs Road,\nCardiff,\nUnite...      03951948    61900
# 3      34, Roundhay Road,\nLeeds,\nEngland,\nLS7 1AB      10530651    78300
# 4  Hestercombe House,\nCheddon Fitzpaine,\nTaunto...      06727055    93110
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   18.0                     28.2                   0.0
# 1                    2.3                     -2.7                  15.0
# ...

# %%
gender_pay_gap_data_201718_df.columns
# Out:
# Index(['EmployerName', 'Address', 'CompanyNumber', 'SicCodes',
#        'DiffMeanHourlyPercent', 'DiffMedianHourlyPercent',
#        'DiffMeanBonusPercent', 'DiffMedianBonusPercent', 'MaleBonusPercent',
#        'FemaleBonusPercent', 'MaleLowerQuartile', 'FemaleLowerQuartile',
#        'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
#        'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
#        'MaleTopQuartile', 'FemaleTopQuartile', 'CompanyLinkToGPGInfo',
#        'ResponsiblePerson', 'EmployerSize', 'CurrentName',
#        'SubmittedAfterTheDeadline'],
#       dtype='object')

# %%
len(gender_pay_gap_data_201718_df)
# Out:
# 10513

# %%
no_nans = gender_pay_gap_data_201718_df.dropna(subset=['CompanyNumber'])

# %%
len(no_nans)
# Out:
# 9167

# %%
company_numbers = no_nans.CompanyNumber.values

# %%
def chunk_maker(iterable, size):
    for i in range(0, len(iterable), size):
        yield iterable[i:i + size]

# %%
# count = 0
# all_officers_df_1 = pd.DataFrame()
# for company_num in company_numbers:
#     if count < 5:
#         qch.format_active_officers_info(
#             qch.query_company_name, qch.query_officers_info, company_num)
#         all_officers_df_1 = all_officers_df_1.append(pd.read_json('{}.txt'.format(company_num)))
#         count += 1
#     else:
#         break

# %%
count = 0
all_officers_df_1 = pd.DataFrame()
for chunk in chunk_maker(company_numbers, 290):
    for company_num in chunk:
        print(company_num)
        qch.format_active_officers_info(
            qch.query_company_name, qch.query_officers_info, company_num)
        all_officers_df_1 = all_officers_df_1.append(
            pd.read_json('companies_house_data/{}.txt'.format(company_num)))        
        count += 1
        print(count)
    time.sleep(300 * 1.5)
# Out:
# 00226143
# 1
# SC016876
# 2
# 03951948
# 3
# 10530651
# 4
# 06727055
# 5
# 07743495
# 6
# 02566586
# 7
# SC272838
# 8
# 08929070
# 9
# SC156515
# 10
# 02826929
# 11
# SC440782
# 12
# SC440783
# 13
# 08942815
# 14
# 08014079
# 15
# 04142000
# 16
# 07431144
# 17
# 03457928
# 18
# 00456846
# 19
# 01123045
# 20
# 06913368
# 21
# 07284675
# 22
# 07923816
# 23
# 05983359
# 24
# 06532691
# 25
# 04437266
# 26
# 00103287
# 27
# 04289561
# 28
# 05192941
# 29
# 08345484
# 30
# 02446884
# 31
# 06865953
# 32
# 08132730
# 33
# 04788424
# 34
# 03591124
# 35
# 04926952
# 04926952 not registered with Companies House
# 36
# 08683274
# 37
# 01543721
# 38
# 00323778
# 39
# 01467761
# 40
# 04168334
# 41
# 03263498
# 42
# 00580331
# 43
# 00391135
# 44
# SC005653
# 45
# 01472970
# 46
# 07160851
# 47
# 00689647
# 48
# 00989239
# 49
# 03262419
# 50
# IP28985R
# 51
# 03506401
# 52
# 00875806
# 53
# 00123458
# 54
# 01585686
# 55
# 03551533
# 56
# 03193203
# 57
# 00193800
# 58
# 03982132
# 59
# 01400901
# 60
# ...

# %%
all_officers_df_1
# Out:
#                             Company_Name Company_Registration_Number  \
# 0        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 1        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 2        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 3        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 4        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 5        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 6        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 7        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 8        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 9        "BRYANSTON SCHOOL",INCORPORATED                      226143
# 10       "BRYANSTON SCHOOL",INCORPORATED                      226143
# 11       "BRYANSTON SCHOOL",INCORPORATED                      226143
# 12       "BRYANSTON SCHOOL",INCORPORATED                      226143
# ...

# %%
all_officers_df_1.shape
# Out:
# (17862, 5)
